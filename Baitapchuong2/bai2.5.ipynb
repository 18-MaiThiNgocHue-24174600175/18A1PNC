# %%
from xml.dom import minidom
doc = minidom.parse("sample.xml")
names = doc.getElementsByTagName("name")
for n in names:
    print(" Name:", n.firstChild.data)
# Out:
#  Name: GeeksForGeeks Company
#  Name: Amar Pandey
#  Name: Akbhar Khan
#  Name: Anthony Walter
