# %%
import pandas as pd
import numpy as np
import io
data = """
country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol,continent
Afghanistan,0,0,0,0.0,AS
Albania,89,132,54,4.9,EU
Algeria,25,0,14,0.7,AF
Andorra,245,138,312,12.4,EU
Angola,217,57,45,5.9,AF
Argentina,193,25,221,8.3,SA
Australia,261,72,212,10.4,OC
Austria,279,75,191,9.7,EU
Azerbaijan,21,46,5,1.3,AS
Bangladesh,0,0,0,0.0,AS
Belarus,42,373,42,14.4,EU
Belgium,295,84,212,10.5,EU
Brazil,245,145,16,7.2,SA
Canada,240,122,100,8.2,NA
China,79,19,45,3.9,AS
Colombia,159,76,3,4.2,SA
Congo (Brazzaville),76,1,9,1.7,AF
Cyprus,192,154,113,8.2,EU
Czechia,361,170,134,10.1,EU
Denmark,224,81,278,10.4,EU
Egypt,6,4,1,0.2,AF
Ecuador,162,74,3,4.2,SA
England,219,126,198,10.1,EU
Ethiopia,20,3,3,0.5,AF
Fiji,77,35,1,1.8,OC
Finland,263,133,97,10.0,EU
France,127,151,370,11.8,EU
Georgia,52,100,149,5.4,AS
Germany,346,117,175,10.4,EU
Ghana,31,3,10,0.9,AF
Greece,133,112,218,8.3,EU
Honduras,69,98,2,3.0,NA
Hungary,234,215,185,11.3,EU
Iceland,233,61,78,6.6,EU
India,9,114,0,2.2,AS
Indonesia,0,0,1,0.0,AS
Ireland,313,118,165,11.4,EU
Italy,85,2,223,6.5,EU
Japan,77,202,16,7.2,AS
Mexico,238,68,7,4.9,NA
Mongolia,77,189,8,4.7,AS
Morocco,12,6,10,0.5,AF
New Zealand,203,79,175,8.4,OC
Nigeria,42,5,2,1.6,AF
Norway,169,71,129,6.7,EU
Peru,210,95,0,6.3,SA
Philippines,71,186,1,4.6,AS
Portugal,194,67,339,11.0,EU
Romania,297,276,86,10.4,EU
Russia,247,326,73,11.5,AS
South Africa,225,76,81,8.2,AF
South Korea,140,16,19,6.5,AS
Spain,284,157,112,10.0,EU
Sweden,190,47,192,7.7,EU
Switzerland,185,100,280,10.2,EU
Thailand,99,258,1,6.4,AS
Turkey,51,22,7,1.4,AS
USA,249,158,84,8.7,NA
Vietnam,111,2,1,2.0,AS
Uruguay,35,220,70,6.6,SA
Venezuela,333,100,3,7.7,SA
Zimbabwe,64,18,4,4.7,AF
"""
df_drinks = pd.read_csv(io.StringIO(data), index_col=0)
df_drinks['continent'] = df_drinks['continent'].fillna('OT')
print("--- 1. Thông tin cơ bản về DataFrame 'df_drinks' ---")
print("\n- Tên các cột (Columns):")
print(df_drinks.columns.tolist())
print("\n- 5 dòng dữ liệu đầu tiên (Head):")
print(df_drinks.head())
print("\n- 5 dòng dữ liệu cuối cùng (Tail):")
print(df_drinks.tail())
print("\n- Kiểu dữ liệu (Dtype):")
print(df_drinks.dtypes)
print(f"\n- Kích thước (Shape): **{df_drinks.shape}** (rows, columns)")
avg_beer_by_continent = df_drinks.groupby('continent')['beer_servings'].mean().round(2)

print("--- 2. Số lượng bia tiêu thụ trung bình (mean) ở mỗi châu lục ---")
print(avg_beer_by_continent)
wine_stats_by_continent = df_drinks.groupby('continent')['wine_servings'].describe().round(2)

print("--- 3. Thống kê tổng quát (describe) số lượng rượu vang (wine_servings) ở mỗi châu lục ---")
print(wine_stats_by_continent)
avg_servings_by_continent = df_drinks.groupby('continent')[['beer_servings', 'spirit_servings', 'wine_servings']].mean().round(2)

print("--- 4. Số lượng các loại bia và rượu tiêu thụ trung bình (mean) ở mỗi châu lục ---")
print(avg_servings_by_continent)
median_servings_by_continent = df_drinks.groupby('continent')[['beer_servings', 'spirit_servings', 'wine_servings']].median().round(2)

print("--- 5. Giá trị trung vị (median) cho các loại bia và rượu tiêu thụ ở mỗi châu lục ---")
print(median_servings_by_continent)
spirit_agg_by_continent = df_drinks.groupby('continent')['spirit_servings'].agg(['mean', 'min', 'max']).round(2)

print("--- 6. Thống kê (mean, min, max) lượng rượu mạnh (spirit_servings) ở mỗi châu lục ---")
print(spirit_agg_by_continent)
df_sorted_beer = df_drinks.sort_values(by='beer_servings', ascending=True)

print("--- 7. Sắp xếp dữ liệu tăng dần theo số lượng bia tiêu thụ ---")
print(df_sorted_beer.head(10)) 
top_5_beer_consumers = df_drinks.sort_values(by='beer_servings', ascending=False).head(5)

print("\n--- 7.a) 5 quốc gia có lượng tiêu thụ bia nhiều nhất ---")
print(top_5_beer_consumers[['beer_servings', 'continent']])
bottom_5_beer_consumers = df_drinks.sort_values(by='beer_servings', ascending=True).head(5)

print("\n--- 7.b) 5 quốc gia có lượng tiêu thụ bia ít nhất ---")
print(bottom_5_beer_consumers[['beer_servings', 'continent']])
# Out:
# --- 1. Thông tin cơ bản về DataFrame 'df_drinks' ---
#
# - Tên các cột (Columns):
# ['beer_servings', 'spirit_servings', 'wine_servings', 'total_litres_of_pure_alcohol', 'continent']
#
# - 5 dòng dữ liệu đầu tiên (Head):
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU
# Angola                                5.9        AF
#
# - 5 dòng dữ liệu cuối cùng (Tail):
# ...
