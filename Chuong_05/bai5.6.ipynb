# %%
import sqlite3
DB_FILE_5_6 = "bai_tap_5_5.db"

print(f"\n--- BÀI 5.6: ĐẾM SỐ BẢN GHI ---")

conn = None
try:
    conn = sqlite3.connect(DB_FILE_5_6)
    cursor = conn.cursor()
    cursor.execute("SELECT COUNT(*) FROM SanPham")
    count = cursor.fetchone()[0]
    
    print(f"🔢 Tổng số bản ghi trong bảng SanPham là: {count}")
    
except sqlite3.Error as e:
    print(f"❌ Lỗi xảy ra: {e}")
finally:
    if conn:
        conn.close()
# Out:
# --- BÀI 5.6: ĐẾM SỐ BẢN GHI ---
# 🔢 Tổng số bản ghi trong bảng SanPham là: 3
